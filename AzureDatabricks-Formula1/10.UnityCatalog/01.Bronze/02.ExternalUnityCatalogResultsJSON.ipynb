-- %% [markdown]
-- #### LOAD `RESULTS.JSON` AS EXTERNAL TABLE

-- %%
DROP TABLE IF EXISTS formulaone_dev.bronze.results;

-- %%
CREATE TABLE IF NOT EXISTS formulaone_dev.bronze.results
(
  resultId INT,
  raceId INT,
  driverId INT,
  constructorId INT,
  number INT,
  grid INT,
  position INT,
  positionText STRING,
  positionOrder INT,
  points FLOAT,
  laps INT,
  time STRING,
  milliseconds INT,
  fastestLap INT,
  rank INT,
  fastestLapTime STRING,
  fastestLapSpeed FLOAT,
  statusId INT
)
USING json
LOCATION 'abfss://f1uc@formula1dbdevadls.dfs.core.windows.net/bronze/results.json';

-- %%
SELECT * FROM formulaone_dev.bronze.results;

-- %%
%py
dbutils.notebook.exit('EXITED SUCCESSFULLY')
