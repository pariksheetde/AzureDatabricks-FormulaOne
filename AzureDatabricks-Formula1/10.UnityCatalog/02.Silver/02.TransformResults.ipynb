-- %%
DROP TABLE IF EXISTS formulaone_dev.silver.results;

-- %%
CREATE TABLE IF NOT EXISTS formulaone_dev.silver.results
AS
  SELECT 
     resultId
    ,raceId
    ,driverId
    ,constructorId
    ,number
    ,grid
    ,position
    ,positionText
    ,positionOrder
    ,points
    ,laps
    ,time
    ,milliseconds
    ,fastestLap
    ,rank
    ,fastestLapTime
    ,fastestLapSpeed
    ,CURRENT_TIMESTAMP() AS ingestion_timestamp
    ,_metadata.file_path AS file_path
   FROM formulaone_dev.bronze.results;

-- %%
SELECT * FROM formulaone_dev.silver.results;

-- %%
%py
dbutils.notebook.exit('EXITED SUCCESSFULLY')
